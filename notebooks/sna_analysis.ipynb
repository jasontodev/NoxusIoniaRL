# %% [markdown]
# # SNA Analysis Notebook
#
# Analysis of agent interactions and team coordination patterns.
#
# See `services/analytics/notebooks/sna_example.ipynb` for the full example.

# %%
# Use the analytics service notebook instead
# See: services/analytics/notebooks/sna_example.ipynb
